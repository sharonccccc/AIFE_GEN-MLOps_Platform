# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import importlib, sys
import demo.agent
importlib.reload(demo.agent)
from demo.agent import pocketflow

# %%
pocketflow({})
# Out:
# ```mermaid
# flowchart TD
#   subgraph Flow["Flow"]
#     N2@{ label: '用戶輸入' }
#     N3@{ label: 'LLM_調用' }
#     N4@{ label: '返回答案' }
#     N3 -- text --> N4
#     N5@{ label: '調用工具' }
#     N6@{ label: '檢查工具' }
#     N7@{ label: '添加消息' }
#     N8@{ label: '正常' }
#     N9@{ label: '提煉' }
#     N9 -- 循環 --> N3
#     N8 -- token溢出 --> N9
#     N10@{ label: '注入變化' }
#     N10 -- default --> N3
#     N8 -- 循環 --> N10
#     N7 -- default --> N8
#     N6 -- default --> N7
#     N5 -- default --> N6
#     N3 -- tools --> N5
#     N2 -- default --> N3
#   end
# {}
